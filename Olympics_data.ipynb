# %%
import pandas as pd

# %%
oly = pd.read_csv('olympics_1896_2004.csv')
oly
# Out:
#       This is a list of medallists at the Summer Olympic Games (1896-2004) with details of the year of the olympics, city, sport, discipline, athlete name, gender, event and medal  \
# 0                                                    NaN
# 1      DISCLAIMER: No guarantees, express or implied,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   Year
# ...                                                  ...
# 27174                                               2004
# 27175                                               2004
# 27176                                               2004
# 27177                                               2004
# 27178                                               2004
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN         NaN                 NaN        NaN
# ...

# %%
oly = pd.read_csv('olympics_1896_2004.csv', skiprows=5)
oly
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
oly.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3

# %%
oly.tail(3)
# Out:
#        Year    City    Sport Discipline       Athlete Name  NOC Gender  \
# 27171  2004  Athens  Fencing    Fencing     BOKEL, Claudia  GER  Women
# 27172  2004  Athens  Fencing    Fencing    DUPLITZER, Imke  GER  Women
# 27173  2004  Athens  Fencing    Fencing  HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2

# %%
oly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27174 entries, 0 to 27173
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          27174 non-null  int64
#  1   City          27174 non-null  object
#  2   Sport         27174 non-null  object
#  3   Discipline    27174 non-null  object
#  4   Athlete Name  27174 non-null  object
#  5   NOC           27174 non-null  object
#  6   Gender        27174 non-null  object
#  7   Event         27174 non-null  object
#  8   Event Gender  27174 non-null  object
#  9   Medal         27174 non-null  object
#  10  Position      27174 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 2.3+ MB

# %%
oly.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %%
oly.Year.value_counts(ascending = True)
# Out:
# Year
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# Name: count, dtype: int64

# %%
oly.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# Position         int64
# dtype: object

# %%
mapper = {"Athlete Name": "Athlete_Name",
          "Event Gender": "Event_Gender"}

# %%
oly = oly.rename(columns=mapper)
oly.sample(3)
# Out:
#        Year         City       Sport     Discipline     Athlete_Name  NOC  \
# 17952  1984  Los Angeles  Volleyball     Volleyball  MONTANARO, Jose  BRA
# 5994   1932  Los Angeles     Cycling  Cycling Track    CHOCQUE, Paul  FRA
# 19308  1988        Seoul   Athletics      Athletics  TIMMERMANN, Ulf  GDR
#
#       Gender                 Event Event_Gender   Medal  Position
# 17952    Men            volleyball            M  Silver         2
# 5994     Men  Team Pursuit (4000m)            M  Silver         2
# 19308    Men              shot put            M    Gold         1

# %%
oly = oly.drop('Position', axis=1)
oly.sample(3)
# Out:
#        Year      City          Sport       Discipline   Athlete_Name  NOC  \
# 433    1900     Paris       Shooting         Shooting  MOREAUX, Léon  FRA
# 8330   1952  Helsinki  Canoe / Kayak  Canoe / Kayak F    DREWS, Egon  GER
# 11343  1964     Tokyo         Hockey           Hockey     SAYED, Ali  IND
#
#       Gender             Event Event_Gender   Medal
# 433      Men  free rifle, team            M  Bronze
# 8330     Men        C-2 10000m            M  Bronze
# 11343    Men            hockey            M    Gold

# %%
oly[(oly.Year > 1896)]
# Out:
#        Year    City    Sport Discipline                 Athlete_Name  NOC  \
# 151    1900   Paris  Sailing    Sailing                 MICHELET, E.  FRA
# 152    1900   Paris  Sailing    Sailing                 MICHELET, F.  FRA
# 153    1900   Paris  Sailing    Sailing             GRETTON, John H.  GBR
# 154    1900   Paris  Sailing    Sailing                 HOPE, Linton  GBR
# 155    1900   Paris  Sailing    Sailing  LORD CURRIE, Lorne Campbell  GBR
# ...     ...     ...      ...        ...                          ...  ...
# 27169  2004  Athens  Fencing    Fencing           LOGOUNOVA, Tatiana  RUS
# 27170  2004  Athens  Fencing    Fencing                SIVKOVA, Anna  RUS
# 27171  2004  Athens  Fencing    Fencing               BOKEL, Claudia  GER
# 27172  2004  Athens  Fencing    Fencing              DUPLITZER, Imke  GER
# 27173  2004  Athens  Fencing    Fencing            HEIDEMANN, Britta  GER
#
#       Gender      Event Event_Gender   Medal
# ...

# %%
oly [(oly.Year == 1896) | (oly.Year == 2004)]
# Out:
#        Year    City      Sport     Discipline        Athlete_Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
oly[(oly.City == 'Athens') & ~(oly.Year == 1896) & (oly.Event == '100m')]
# Out:
#        Year    City      Sport Discipline              Athlete_Name  NOC  \
# 25232  2004  Athens  Athletics  Athletics           GREENE, Maurice  USA
# 25233  2004  Athens  Athletics  Athletics            GATLIN, Justin  USA
# 25234  2004  Athens  Athletics  Athletics         OBIKWELU, Francis  POR
# 25235  2004  Athens  Athletics  Athletics  CAMPBELL-BROWN, Veronica  JAM
# 25236  2004  Athens  Athletics  Athletics        NESTERENKO, Yuliya  BLR
# 25237  2004  Athens  Athletics  Athletics          WILLIAMS, Lauryn  USA
#
#       Gender Event Event_Gender   Medal
# 25232    Men  100m            M  Bronze
# 25233    Men  100m            M    Gold
# 25234    Men  100m            M  Silver
# 25235  Women  100m            W  Bronze
# 25236  Women  100m            W    Gold
# 25237  Women  100m            W  Silver

# %%
oly.Event.str.capitalize().unique().tolist()
# Out:
# ['100km',
#  '100m',
#  '100m freestyle',
#  '100m freestyle for sailors',
#  '10km',
#  '110m hurdles',
#  '12-hour race',
#  '1200m freestyle',
#  '1500m',
#  '1km time trial',
#  '25m army pistol',
#  '25m rapid fire pistol (60 shots)',
#  '400m',
#  '400m freestyle',
#  '50m pistol (60 shots)',
#  '800m',
#  'Sprint indivual',
#  'Army rifle, 200m',
#  'Army rifle, 300m',
#  'Discus throw',
#  'Doubles',
#  'Foil individual',
#  'Foil, masters',
#  'Heavyweight - one hand lift',
#  'Heavyweight - two hand lift',
#  'High jump',
#  'Horizontal bar',
#  'Individual road race',
#  'Long jump',
#  'Marathon',
#  'Open event',
#  'Parallel bars',
#  'Pole vault',
#  'Pommel horse',
#  'Rings',
#  'Rope climbing',
#  'Sabre individual',
#  'Shot put',
#  'Singles',
#  'Team, horizontal bar',
#  'Team, parallel bars',
#  'Triple jump',
#  'Vault',
#  '0.5-1t',
#  '10-20t',
#  '1500m freestyle',
#  '200m',
#  '200m backstroke',
#  '200m freestyle',
#  '200m hurdles',
# ...

# %%
oly[oly["Athlete_Name"].str.contains("LATYNINA")]
# Out:
#        Year                   City       Sport   Discipline      Athlete_Name  \
# 9372   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9539   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9679   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9702   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9735   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9741   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10179  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10277  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10458  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10576  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10612  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# ...

# %%
oly.sort_values(by=["Year", "Event", "Medal"], ascending=[True,True,False]).head(5)
# Out:
#    Year    City      Sport     Discipline        Athlete_Name  NOC Gender  \
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 5  1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
#
#    Event Event_Gender   Medal
# 1  100km            M  Silver
# 0  100km            M    Gold
# 5   100m            M  Silver
# 4   100m            M    Gold
# 2   100m            M  Bronze

# %%
oly.dtypes
oly_Medal = oly.Medal.astype("category")
medal_order = ["Bronze", "Silver", "Gold"]
pd.Categorical(oly.Medal, categories = medal_order, ordered=True)
# Out:
# ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold', ..., 'Gold', 'Gold', 'Silver', 'Silver', 'Silver']
# Length: 27174
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %%
oly.Medal = oly.Medal.astype("category")
oly.Gender = oly.Gender.astype("category")
oly["Event_Gender"] = oly["Event_Gender"].astype("category")

# %%
oly.City = oly.City.astype("string")
oly.Sport = oly.Sport.astype("string")
oly.Discipline = oly.Discipline.astype("string")
oly["Athlete_Name"] = oly["Athlete_Name"].astype("string")
oly.NOC = oly.NOC.astype("string")
oly.Event = oly.Event.astype("string")
oly.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete_Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event_Gender          category
# Medal                 category
# dtype: object

# %%
ordered_medals = pd.api.types.CategoricalDtype(categories=medal_order, ordered=True)
ordered_medals
# Out:
# CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True, categories_dtype=object)

# %%
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete_Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_Gender": "category",
                "Medal": ordered_medals}

dtype_mapper
# Out:
# {'Year': 'int64',
#  'City': 'string',
#  'Sport': 'string',
#  'Discipline': 'string',
#  'Athlete_Name': 'string',
#  'NOC': 'string',
#  'Gender': 'category',
#  'Event': 'string',
#  'Event_Gender': 'category',
#  'Medal': CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True, categories_dtype=object)}

# %%
filename = "olympics_1896_2004.csv"
oly = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
oly.sample(3)
# Out:
#        Year     City      Sport       Discipline     Athlete Name  NOC Gender  \
# 4369   1924    Paris  Wrestling  Wrestling Free.  NEWTON, Chester  USA    Men
# 22322  1996  Atlanta   Football         Football         ZE MARIA  BRA    Men
# 165    1900    Paris  Athletics        Athletics  ROWLEY, Stanley  AUS    Men
#
#                            Event Event Gender   Medal  Position
# 4369   56 - 61kg (featherweight)            M  Silver         2
# 22322                   football            M  Bronze         3
# 165                         100m            M  Bronze         3

# %%
def show_df(filename="olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event Gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop("Position",axis=1))
  return df

ol = show_df()
ol.head(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
#
#    Event Event Gender   Medal
# 0  100km            M    Gold
# 1  100km            M  Silver
# 2   100m            M  Bronze

# %%
ol[ol['Athlete Name'].str.contains("LEWIS, Carl")]
# Out:
#        Year         City      Sport Discipline Athlete Name  NOC Gender  \
# 16636  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 16697  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 16847  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 17709  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 18098  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men
# 18165  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men
# 19227  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men
# 19908  1992    Barcelona  Athletics  Athletics  LEWIS, Carl  USA    Men
# 20917  1992    Barcelona  Athletics  Athletics  LEWIS, Carl  USA    Men
# 22719  1996      Atlanta  Athletics  Athletics  LEWIS, Carl  USA    Men
#
#               Event Event Gender   Medal
# 16636          100m            M    Gold
# 16697          200m            M    Gold
# 16847  4x100m relay            M    Gold
# ...

# %%
ol.loc[22719,"Event"]
# Out:
# 'long jump'

# %%
assert(ol[(ol.Year < 1896) & (ol.Year > 2004)].shape[0] == 0)
print("Everything is alright, All test cases passed!!!")
# Out:
# Everything is alright, All test cases passed!!!

# %%
exp1 = ol.set_index("Athlete Name")
exp1.iloc[0,:]
# Out:
# Year                     1896
# City                   Athens
# Sport                 Cycling
# Discipline      Cycling Track
# NOC                       FRA
# Gender                    Men
# Event                   100km
# Event Gender                M
# Medal                    Gold
# Name: FLAMENG, Léon, dtype: object

# %%
exp1.loc["LEWIS, Carl", ["Year", "Event", "Medal"]]
# Out:
#               Year         Event   Medal
# Athlete Name
# LEWIS, Carl   1984          100m    Gold
# LEWIS, Carl   1984          200m    Gold
# LEWIS, Carl   1984  4x100m relay    Gold
# LEWIS, Carl   1984     long jump    Gold
# LEWIS, Carl   1988          100m    Gold
# LEWIS, Carl   1988          200m  Silver
# LEWIS, Carl   1988     long jump    Gold
# LEWIS, Carl   1992  4x100m relay    Gold
# LEWIS, Carl   1992     long jump    Gold
# LEWIS, Carl   1996     long jump    Gold

# %% [markdown]
# **New file containing data for Olympic 2008**

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  return df

new_ol = preprocess_2008()
new_ol.sample(3)
# Out:
#          City    Year      Sport Discipline      Athlete Name  NOC Gender  \
# 511   Beijing  2008.0  athletics  Athletics     ZHANG, Wenxiu  CHN  Women
# 1452  Beijing  2008.0       judo       Judo     PAK, Chol Min  PRK    Men
# 1105  Beijing  2008.0   football   Football  BARNHART, Nicole  USA  Women
#
#                              Event Event Gender   Medal
# 511                   hammer throw            W  bronze
# 1452  60 - 66kg (half-lightweight)            M  bronze
# 1105                      football            W    gold

# %%
new_ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2033 non-null   object
#  1   Year          2025 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
import re
import pandas as pd

sch_str = "na"

[func for func in dir(pd) if re.search(rf"{sch_str}", func, re.IGNORECASE)]
# Out:
# ['NA', 'NaT', 'NamedAgg', '__name__', 'isna', 'notna']

# %%
new_ol[new_ol.isna()]
# Out:
#      City  Year Sport Discipline Athlete Name  NOC Gender Event Event Gender  \
# 0     NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 1     NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 2     NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 3     NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 4     NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# ...   ...   ...   ...        ...          ...  ...    ...   ...          ...
# 2054  NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 2055  NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 2056  NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 2057  NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
# 2058  NaN   NaN   NaN        NaN          NaN  NaN    NaN   NaN          NaN
#
#      Medal
# 0      NaN
# 1      NaN
# ...

# %%
new_ol.isna().sum()
# Out:
# City            26
# Year            34
# Sport           11
# Discipline      11
# Athlete Name    11
# NOC             11
# Gender          11
# Event           11
# Event Gender    11
# Medal           11
# dtype: int64

# %%
new_ol.City.unique()
# Out:
# array(['Beijing', nan], dtype=object)

# %%
new_ol.City = new_ol.City.fillna(value="Beijing")
new_ol.City.unique()
# Out:
# array(['Beijing'], dtype=object)

# %%
print(new_ol.Year.unique())
new_ol.Year = new_ol.Year.fillna(value=2008)
new_ol.Year.unique()
# Out:
# [2008.   nan]
# array([2008.])

# %%
new_ol.dropna(how="all", axis=0)
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN
# ...       ...     ...        ...              ...               ...  ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
#
#      Gender         Event Event Gender   Medal
# ...

# %%
new_ol.info()
new_ol.dropna(how="any", axis=0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2059 non-null   object
#  1   Year          2059 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB
#          City    Year      Sport       Discipline      Athlete Name  NOC  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS
# ...

# %%
new_ol[new_ol.Sport.isna()]
# Out:
#         City    Year Sport Discipline Athlete Name  NOC Gender Event  \
# 62   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 63   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 64   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 65   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 66   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 67   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 68   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 69   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 70   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 220  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 221  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
#
#     Event Gender Medal
# 62           NaN   NaN
# 63           NaN   NaN
# 64           NaN   NaN
# 65           NaN   NaN
# ...

# %%
new_ol = new_ol.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
new_ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2048 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2048 non-null   object
#  1   Year          2048 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 176.0+ KB

# %%
print(f"Number of dulpicate entries in the data: {new_ol.duplicated().sum()}")
new_ol.loc[new_ol.duplicated(), :]
# Out:
# Number of dulpicate entries in the data: 6
#          City    Year      Sport       Discipline    Athlete Name  NOC Gender  \
# 2053  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
#
#            Event Event Gender   Medal
# 2053  96 - 120kg            M  silver
# 2054  96 - 120kg            M  silver
# 2055  96 - 120kg            M  silver
# 2056  96 - 120kg            M  silver
# 2057  96 - 120kg            M  silver
# 2058  96 - 120kg            M  silver

# %%
print(new_ol.shape)
new_ol = new_ol.drop_duplicates()
new_ol.shape
# Out:
# (2048, 10)
# (2042, 10)

# %%
new_ol['Event Gender'].unique()
# Out:
# array(['M', 'W', 'X'], dtype=object)

# %%
new_ol.loc[(new_ol["Event Gender"] == "F") & (new_ol.Gender != "Women")]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
ol.sample(5)
# Out:
#        Year                   City          Sport       Discipline  \
# 9383   1956  Melbourne / Stockholm        Fencing          Fencing
# 23803  2000                 Sydney  Canoe / Kayak  Canoe / Kayak S
# 2936   1920                Antwerp        Sailing          Sailing
# 11595  1964                  Tokyo     Volleyball       Volleyball
# 574    1900                  Paris          Rugby            Rugby
#
#                Athlete Name  NOC Gender               Event Event Gender  \
# 9383          SOMODI, Lajos  HUN    Men           foil team            M
# 23803       RATCLIFFE, Paul  GBR    Men  K-1 (kayak single)            M
# 2936   ÖSTERVOLD, Ole Olsen  NOR    Men   12m (rating 1907)            X
# 11595       TOMAN, Ladislav  TCH    Men          volleyball            M
# 574    WHITTINDALE, Raymond  GBR    Men               rugby            M
#
#         Medal
# 9383   Bronze
# 23803  Silver
# 2936     Gold
# 11595  Silver
# 574    Silver

# %%
ol["Event Gender"].unique()
# Out:
# ['M', 'X', 'W']
# Categories (3, object): ['M', 'W', 'X']

# %%
assert(sorted(ol["Event Gender"].unique().tolist()) == sorted(new_ol["Event Gender"].unique().tolist()))
print("Everything is alright, All test cases passed!!!")
# Out:
# Everything is alright, All test cases passed!!!

# %%
new_ol.Medal = new_ol.Medal.str.capitalize()
new_ol.sample(5)
# Out:
# <ipython-input-166-37ab3111848a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ol.Medal = new_ol.Medal.str.capitalize()
#          City    Year       Sport  Discipline          Athlete Name  NOC  \
# 1603  Beijing  2008.0      rowing      Rowing      JELINSKI, Michal  POL
# 143   Beijing  2008.0    aquatics    Swimming  SCHREUDER, Hinkelien  NED
# 685   Beijing  2008.0  basketball  Basketball           LOPEZ, Raul  ESP
# 508   Beijing  2008.0   athletics   Athletics         TSIKHAN, Ivan  BLR
# 1613  Beijing  2008.0      rowing      Rowing        OPPELT, Britta  GER
#
#      Gender                                   Event Event Gender   Medal
# 1603    Men  quadruple sculls without coxswain (4x)            M    Gold
# ...

# %%
assert(sorted(new_ol.Gender.unique().tolist()) == sorted(ol.Gender.unique().tolist()))
assert(sorted(new_ol.Medal.unique().tolist()) == sorted(ol.Medal.unique().tolist()))
print("Going good, Keep it up!!")
# Out:
# Going good, Keep it up!!

# %%
new_ol.Sport = new_ol.Sport.str.lower()
new_ol.Discipline = new_ol.Discipline.str.lower()
new_ol.Event = new_ol.Event.str.lower()
new_ol.NOC = new_ol.NOC.str.upper()
new_ol.sample(3)
# Out:
# <ipython-input-168-de7bb6c60507>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ol.Sport = new_ol.Sport.str.lower()
# <ipython-input-168-de7bb6c60507>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ol.Discipline = new_ol.Discipline.str.lower()
# <ipython-input-168-de7bb6c60507>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
athlete_names_split = new_ol["Athlete Name"].str.split(", ").tolist()
athlete_names_split
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
# ...

# %%
import re

search_string = "upper"

[func for func in dir(new_ol["Athlete Name"].str) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['isupper', 'upper']

# %%
len([item[0].isupper() for item in athlete_names_split])
# Out:
# 2042

# %%
new_ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2042 entries, 0 to 2052
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2042 non-null   object
#  1   Year          2042 non-null   float64
#  2   Sport         2042 non-null   object
#  3   Discipline    2042 non-null   object
#  4   Athlete Name  2042 non-null   object
#  5   NOC           2042 non-null   object
#  6   Gender        2042 non-null   object
#  7   Event         2042 non-null   object
#  8   Event Gender  2042 non-null   object
#  9   Medal         2042 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 175.5+ KB

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event Gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.loc[24676, "Gender"] = "Women"
  return df

def preprocess_2008(filename = "olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oly_old = preprocess()
oly_new = preprocess_2008()
oly_new.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#          City  Year       Sport   Discipline      Athlete Name  NOC Gender  \
# 952   Beijing  2008  equestrian     eventing    KLIMKE, Ingrid  GER  Women
# 1170  Beijing  2008  gymnastics  artistic g.     HAGERTY, Joey  USA    Men
# 1690  Beijing  2008    shooting     shooting  EMMONS, Katerina  CZE  Women
#
#                          Event Event Gender   Medal
# 952                       team            X    Gold
# 1170          team competition            M  Bronze
# 1690  10m air rifle (40 shots)            W    Gold

# %%
oly_old.sample(3)
# Out:
#        Year         City       Sport    Discipline     Athlete Name  NOC  \
# 26387  2004       Athens  gymnastics   rhythmic g.  VERNIZZI, Laura  ITA
# 6139   1932  Los Angeles      hockey        hockey    SAKAI, Yoshio  JPN
# 17698  1984  Los Angeles     cycling  cycling road   BAUER, Stephen  CAN
#
#       Gender                 Event Event Gender   Medal
# 26387  Women     group competition            W  Silver
# 6139     Men                hockey            M  Silver
# 17698    Men  individual road race            M  Silver

# %%
oly_old.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
oly_new.dtypes
# Out:
# City            string[python]
# Year                     int64
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
pd.concat([oly_old,oly_new]).dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
up_com = pd.concat([oly_old,oly_new])
up_com.sample(3)
# Out:
#        Year      City      Sport       Discipline       Athlete Name  NOC  \
# 14070  1976  Montreal  wrestling  wrestling free.      JEON, Hae-Sup  KOR
# 18767  1988     Seoul     tennis           tennis    TURNBULL, Wendy  AUS
# 1689   1908    London      rugby            rugby  BEDE-SMITH, Frank  ANZ
#
#       Gender                  Event Event Gender   Medal
# 14070    Men  48 - 52kg (flyweight)            M  Bronze
# 18767  Women                doubles            W  Bronze
# 1689     Men                  rugby            M    Gold

# %%
up_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29216 entries, 0 to 2052
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          29216 non-null  int64
#  1   City          29216 non-null  string
#  2   Sport         29216 non-null  string
#  3   Discipline    29216 non-null  string
#  4   Athlete Name  29216 non-null  string
#  5   NOC           29216 non-null  string
#  6   Gender        29216 non-null  category
#  7   Event         29216 non-null  string
#  8   Event Gender  29216 non-null  category
#  9   Medal         29216 non-null  category
# dtypes: category(3), int64(1), string(6)
# memory usage: 1.9 MB

# %%
up_com.groupby(["NOC"])["Year"].agg(["min", "max", "count"])
# Out:
#       min   max  count
# NOC
# AFG  2008  2008      1
# AHO  1988  1988      1
# ALG  1984  2008     14
# ANZ  1908  1912     29
# ARG  1924  2008    239
# ..    ...   ...    ...
# VIE  2000  2008      2
# YUG  1924  2000    435
# ZAM  1984  1996      2
# ZIM  1980  2008     23
# ZZX  1896  1904     48
#
# [138 rows x 3 columns]

# %%
sprints = up_com[(up_com.Year == 2008) & ((up_com.Event == '100m') | (up_com.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA
#
# ...

# %%
exp2 = sprints.groupby(["NOC", "Gender", "Event"]).size()
exp2
# Out:
# <ipython-input-211-893a1c884f1c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   exp2 = sprints.groupby(["NOC", "Gender", "Event"]).size()
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
#      Women   100m     3
#              200m     2
# TRI  Men     100m     1
#              200m     0
#      Women   100m     0
#              200m     0
# USA  Men     100m     1
#              200m     2
#      Women   100m     0
#              200m     1
# dtype: int64

# %%
exp2.unstack("Gender", fill_value = 0).unstack("Event", fill_value = 0)
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %% [markdown]
# **Plots**

# %%
import matplotlib.pyplot as plt

# %%
first_games = up_com[up_com.Year == 1896]
first_games
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     cycling  cycling track         FLAMENG, Léon  FRA
# 1    1896  Athens     cycling  cycling track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   athletics      athletics         LANE, Francis  USA
# 3    1896  Athens   athletics      athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   athletics      athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   athletics      athletics       CONNOLLY, James  USA
# 147  1896  Athens   athletics      athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  gymnastics    artistic g.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  gymnastics    artistic g.        SCHUMANN, Carl  GER
# 150  1896  Athens  gymnastics    artistic g.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# ...

# %%
first_games.Sport.value_counts().plot(kind='barh', color=['#bfcbdb', '#e14b31'])
# Out:
# <Axes: ylabel='Sport'>

# %%
import seaborn as sns

# %%
games_2008 = up_com[up_com.Year == 2008]
games_2008.sample(3)
# Out:
#      Year     City      Sport  Discipline         Athlete Name  NOC Gender  \
# 565  2008  Beijing  badminton   badminton             CAI, Yun  CHN    Men
# 310  2008  Beijing   aquatics  water polo        HUDNUT, Peter  USA    Men
# 490  2008  Beijing  athletics   athletics  NIZHEGORODOV, Denis  RUS    Men
#
#           Event Event Gender   Medal
# 565     doubles            M  Silver
# 310  water polo            M  Silver
# 490   50km walk            M  Bronze

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"])
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='coolwarm')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>
